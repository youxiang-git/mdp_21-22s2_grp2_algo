# %%
import networkx as nx
import matplotlib
import numpy as np

def calc_TSP(node_c):
    g1 = nx.complete_graph(6)

    node_c_no_h = []
    for x in node_c:
        node_c_no_h.append(x[:2])

    print(node_c_no_h)

    for node, node2 in g1.edges:
        # print(node_c[node], node_c[node2])
        print(node, node2)
        # print(g1[node][node2])
        xy = np.subtract(node_c_no_h[node], node_c_no_h[node2])
        xy = np.abs(xy)
        print(xy)
        xy = np.sum(xy)
        g1[node][node2]['weight'] = xy
        # print(g1[node][node2]['weight'])

    print(g1[0])

    nx.draw(g1, node_c_no_h, with_labels = True)
    labels = nx.get_edge_attributes(g1,'weight')
    nx.draw_networkx_edge_labels(g1,node_c_no_h,edge_labels=labels)
    tsp_path = nx.approximation.traveling_salesman_problem(g1, weight = 'weight', cycle = True, method = nx.algorithms.approximation.traveling_salesman.greedy_tsp)
    return tsp_path


def main():
    c_list = [(1, 17, 0), (16, 2, 90), (3, 2, 90), (16, 12, 90), (7, 7, 90), (13, 6, 90)]
    tsp_p = calc_TSP(c_list)
    print(tsp_p)

main()
# Out:
# [(1, 17), (16, 2), (3, 2), (16, 12), (7, 7), (13, 6)]
# 0 1
# [15 15]
# 0 2
# [ 2 15]
# 0 3
# [15  5]
# 0 4
# [ 6 10]
# 0 5
# [12 11]
# 1 2
# [13  0]
# 1 3
# [ 0 10]
# 1 4
# [9 5]
# 1 5
# [3 4]
# 2 3
# [13 10]
# 2 4
# [4 5]
# 2 5
# [10  4]
# 3 4
# [9 5]
# 3 5
# [3 6]
# 4 5
# [6 1]
# {1: {'weight': 30}, 2: {'weight': 17}, 3: {'weight': 20}, 4: {'weight': 16}, 5: {'weight': 23}}
# [0, 4, 5, 1, 3, 2, 0]
