# %%
import networkx as nx
import matplotlib
import numpy as np

def calc_TSP(node_c):
    g1 = nx.complete_graph(len(node_c))

    node_c_no_h = []
    for x in node_c:
        node_c_no_h.append(x[:2])

    print(node_c_no_h)

    for node, node2 in g1.edges:
        # print(node_c[node], node_c[node2])
        print(node, node2)
        # print(g1[node][node2])
        xy = np.subtract(node_c_no_h[node], node_c_no_h[node2])
        xy = np.abs(xy)
        print(xy)
        xy = np.sum(xy)
        g1[node][node2]['weight'] = xy
        # print(g1[node][node2]['weight'])

    print(g1)

    nx.draw(g1, node_c_no_h, with_labels = True)
    labels = nx.get_edge_attributes(g1,'weight')
    nx.draw_networkx_edge_labels(g1,node_c_no_h,edge_labels=labels)
    tsp_path = nx.approximation.traveling_salesman_problem(g1, weight = 'weight', cycle = True, method = nx.algorithms.approximation.traveling_salesman.greedy_tsp)
    return tsp_path


def main():
    c_list = [(2, 18, 90), (4, 2, 90), (16, 6, 90), (4, 9, 90), (14, 16, 90), (11, 10, 90)]
    tsp_p = calc_TSP(c_list)
    print(tsp_p)

main()
# Out:
# [(2, 18), (4, 2), (16, 6), (4, 9), (14, 16), (11, 10)]
# 0 1
# [ 2 16]
# 0 2
# [14 12]
# 0 3
# [2 9]
# 0 4
# [12  2]
# 0 5
# [9 8]
# 1 2
# [12  4]
# 1 3
# [0 7]
# 1 4
# [10 14]
# 1 5
# [7 8]
# 2 3
# [12  3]
# 2 4
# [ 2 10]
# 2 5
# [5 4]
# 3 4
# [10  7]
# 3 5
# [7 1]
# 4 5
# [3 6]
# Graph with 6 nodes and 15 edges
# [0, 3, 1, 5, 2, 4, 0]
